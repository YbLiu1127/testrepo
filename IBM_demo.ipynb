# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#   **My name is Yen Po Liu**
#   **I want to be a data analyst**

# %% [markdown]
# *I am interested in data science because data is now all over our life, with data science, we could extend our ability by predict future more accurately, which means to a certain degree,  people could break time limit and gain profit from it.*

# %% [markdown]
# ### The following code display 1 multiply with 3 ###

# %%
a=1
b=3
print(a*b)
# Out:
# 3

# %% [markdown]
# ***
# ---
# * A
# + B
# - C
#
# 1. D
# 2. E
# 3. F
